# %%
# viz_embeddings_fiftyone.py
import time
import torch
import numpy as np
import fiftyone as fo
import fiftyone.brain as fob
from fiftyone import Classification, Classifications
from torch.utils.data import TensorDataset, DataLoader

# %%
def _load_concat_dataset(embed_paths, label_paths):
    """
    Load multiple .pt files and concatenate along dim 0
    """
    X_list = [torch.load(p) for p in embed_paths]
    y_list = [torch.load(p) for p in label_paths]
    
    X = torch.cat(X_list, dim=0)
    y = torch.cat(y_list, dim=0)
    
    return TensorDataset(X, y)

# %%
val_ds = _load_concat_dataset(
    [
        '/home/free4ky/projects/chest-diseases/data/preprocessed_mosmed/test_data.pt',
        '/home/free4ky/projects/chest-diseases/data/preprocessed_val_20/validation_data.pt'
    ],
    [
        '/home/free4ky/projects/chest-diseases/data/preprocessed_mosmed/test_labels.pt',
        '/home/free4ky/projects/chest-diseases/data/preprocessed_val_20/validation_labels.pt'
    ]
)

# %%
# --- 1) load your .pt files (embeddings: [N,512], labels: [N,20]) ---


emb = val_ds.tensors[0]
labels = val_ds.tensors[1]

# to numpy (safe for GPU tensors)
if isinstance(emb, torch.Tensor):
    emb = emb.detach().cpu().numpy()
if isinstance(labels, torch.Tensor):
    labels = labels.detach().cpu().numpy()

# basic validation
if emb.ndim != 2:
    raise ValueError(f"embeddings must be 2D (n_samples x n_dims); got shape {emb.shape}")
if labels.ndim != 2:
    raise ValueError(f"labels must be 2D (n_samples x n_classes); got shape {labels.shape}")
n_samples, emb_dim = emb.shape
if labels.shape[0] != n_samples:
    raise ValueError("number of rows in embeddings and labels must match")

n_classes = labels.shape[1]

# --- 2) create class names (or provide your own list) ---
# If you already have human-readable class names, replace this list
class_names = [f"class_{i}" for i in range(n_classes)]

# --- 3) convert label vectors to lists of class-names per sample ---
# If your labels are probabilities/floats, we threshold at 0.5;
# if they're already binary (0/1) this also works.
if np.issubdtype(labels.dtype, np.floating):
    label_mask = labels >= 0.5
else:
    # ints / bools
    label_mask = labels.astype(bool)

label_lists = [
    [class_names[j] for j, present in enumerate(row) if present]
    for row in label_mask
]

# optional: a "top label" per sample for simpler single-color visualizations
top_labels = [lst[0] if len(lst) else "NONE" for lst in label_lists]

# --- 4) create a FiftyOne dataset (samples with a multilabel field) ---
# Use a timestamped name to avoid clobbering existing datasets
dataset_name = f"embeddings_viz_{int(time.time())}"
dataset = fo.Dataset(dataset_name)

# Build fo.Sample objects in the same order as the rows in `emb`
samples = []
for i, labs in enumerate(label_lists):
    # sample filepath is a placeholder — replace with your real image paths if you have them
    sample = fo.Sample(filepath=f"sample_{i}.jpg")
    # store multilabels in a label field (optional, useful in the app)
    sample["labels_mult"] = Classifications(
        classifications=[Classification(label=l) for l in labs]
    )
    samples.append(sample)

dataset.add_samples(samples)  # add all at once (fast)

# --- 5) compute a 2D visualization (UMAP) from your precomputed embeddings ---
# We pass the raw embeddings array aligned to the dataset order
# method: "umap" (default options can be tuned via kwargs)
results = fob.compute_visualization(
    dataset,
    embeddings=emb,   # numpy array of shape (n_samples, emb_dim)
    method="umap",    # 'umap' | 'tsne' | 'pca' (FiftyOne supports these)
    num_dims=2,       # 2D for interactive plots
)

# --- 6) show an interactive scatterplot colored by your multilabels ---
# Option A: color by the full multilabel lists (each point may appear under multiple classes)
plot = results.visualize(labels=label_lists)   # labels can be a list-of-lists
plot.show()  # opens an interactive window / notebook renderer

# Option B: color by a single label per sample (e.g., top_labels)
# plot = results.visualize(labels=top_labels)
# plot.show()

# --- 7) (optional) index the 2D points back into the dataset for lasso selection & querying ---
# store points into a sample field "umap_points"; create a spatial index for fast queries
results.index_points(points_field="umap_points", create_index=True)

# --- 8) (optional) attach the plot to a FiftyOne App session for synced exploration ---
session = fo.launch_app(dataset)          # launches the FiftyOne App in your browser
session.plots["embeddings_umap"] = plot   # adds the interactive plot to the App
print(f"Dataset: {dataset_name} — open FiftyOne App to explore samples & the embeddings plot.")
# Out:
# ---------------------------------------------------------------------------
# ServiceExecutableNotFound                 Traceback (most recent call last)
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/odm/database.py:204, in establish_db_conn(config)
#     203 try:
# --> 204     _db_service = fos.DatabaseService()
#     205     port = _db_service.port
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/service.py:81, in Service.__init__(self)
#      80 if not self._disabled:
# ---> 81     self.start()
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/service.py:210, in MultiClientService.start(self)
#     208         logger.warning("%s did not respond", desc)
# --> 210 super().start()
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/service.py:119, in Service.start(self)
#     114 # use psutil's Popen wrapper because its wait() more reliably waits
#     115 # for the process to exit on Windows
#     116 self.child = psutil.Popen(
#     117     [sys.executable, service_main_path]
#     118     + self._service_args
# --> 119     + self.command,
#     120     cwd=self.working_dir,
#     121     stdin=subprocess.PIPE,
#     122     env={**os.environ, "FIFTYONE_DISABLE_SERVICES": "1", **self.env},
#     123 )
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/service.py:239, in DatabaseService.command(self)
#     236 log_path = os.path.join(database_dir, "log", "mongo.log")
#     238 args = [
# --> 239     DatabaseService.find_mongod(),
#     240     "--dbpath",
#     241     database_dir,
#     242     "--logpath",
#     243     log_path,
#     244     "--port",
#     245     "0",
#     246 ]
#     247 if not sys.platform.startswith("win"):
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/service.py:287, in DatabaseService.find_mongod()
#     286 if not os.path.isfile(mongod):
# --> 287     raise ServiceExecutableNotFound("Could not find `mongod`")
#     289 if not os.access(mongod, os.X_OK):
#
# ServiceExecutableNotFound: Could not find `mongod`
#
# During handling of the above exception, another exception occurred:
#
# FiftyOneConfigError                       Traceback (most recent call last)
# Cell In[8], line 48
#      45 # --- 4) create a FiftyOne dataset (samples with a multilabel field) ---
#      46 # Use a timestamped name to avoid clobbering existing datasets
#      47 dataset_name = f"embeddings_viz_{int(time.time())}"
# ---> 48 dataset = fo.Dataset(dataset_name)
#      50 # Build fo.Sample objects in the same order as the rows in `emb`
#      51 samples = []
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/singletons.py:51, in DatasetSingleton.__call__(cls, name, _create, _reload, *args, **kwargs)
#      43 instance = cls._instances.pop(name, None)
#      45 if (
#      46     _create
#      47     or instance is None
#      48     or instance.deleted
#      49     or instance.name is None
#      50 ):
# ---> 51     instance = cls._make_instance(
#      52         name=name, _create=_create, *args, **kwargs
#      53     )
#      54     name = instance.name  # `__init__` may have changed `name`
#      55 else:
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/singletons.py:35, in DatasetSingleton._make_instance(cls, name, _create, *args, **kwargs)
#      33 def _make_instance(cls, name, _create, *args, **kwargs):
#      34     instance = cls.__new__(cls)
# ---> 35     instance.__init__(name=name, _create=_create, *args, **kwargs)
#      36     return instance
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/dataset.py:328, in Dataset.__init__(self, name, persistent, overwrite, _create, _virtual, _reload, **kwargs)
#     325     delete_dataset(name)
#     327 if _create:
# --> 328     doc, sample_doc_cls, frame_doc_cls = _create_dataset(
#     329         self, name, persistent=persistent, **kwargs
#     330     )
#     331 else:
#     332     doc, sample_doc_cls, frame_doc_cls = _load_dataset(
#     333         self, name, virtual=_virtual
#     334     )
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/dataset.py:8471, in _create_dataset(obj, name, persistent, _patches, _frames, _clips, _src_collection)
#    8462 def _create_dataset(
#    8463     obj,
#    8464     name,
#    (...)   8469     _src_collection=None,
#    8470 ):
# -> 8471     slug = _validate_dataset_name(name)
#    8473     _id = ObjectId()
#    8474     now = datetime.utcnow()
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/dataset.py:127, in _validate_dataset_name(name, skip)
#     124 if skip is not None:
#     125     query = {"$and": [query, {"_id": {"$ne": skip._doc.id}}]}
# --> 127 conn = foo.get_db_conn()
#     129 clashing_name_doc = conn.datasets.find_one(
#     130     query, {"name": True, "_id": False}
#     131 )
#     132 if clashing_name_doc is not None:
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/odm/database.py:484, in get_db_conn()
#     478 def get_db_conn():
#     479     """Returns a connection to the database.
#     480
#     481     Returns:
#     482         a ``pymongo.database.Database``
#     483     """
# --> 484     _connect()
#     485     db = _client[fo.config.database_name]
#     486     return _apply_options(db)
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/odm/database.py:246, in _connect()
#     243 if _client is None:
#     244     global _connection_kwargs
# --> 246     establish_db_conn(fo.config)
#
# File ~/projects/chest-diseases/venv/lib/python3.11/site-packages/fiftyone/core/odm/database.py:210, in establish_db_conn(config)
#     207         os.environ["FIFTYONE_PRIVATE_DATABASE_PORT"] = str(port)
#     209     except fos.ServiceExecutableNotFound:
# --> 210         raise FiftyOneConfigError(
#     211             "MongoDB could not be installed on your system. Please "
#     212             "define a `database_uri` in your "
#     213             "`fiftyone.core.config.FiftyOneConfig` to connect to your"
#     214             "own MongoDB instance or cluster "
#     215         )
#     217 _client = pymongo.MongoClient(
#     218     **_connection_kwargs, appname=foc.DATABASE_APPNAME
#     219 )
#     220 _validate_db_version(config, _client)
#
# FiftyOneConfigError: MongoDB could not be installed on your system. Please define a `database_uri` in your `fiftyone.core.config.FiftyOneConfig` to connect to yourown MongoDB instance or cluster
